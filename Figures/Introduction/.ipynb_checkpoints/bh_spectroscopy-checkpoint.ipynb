# %%
import numpy as np
import qnmfits.qnm as qnm

import matplotlib.pyplot as plt
import rcparams
plt.rcParams.update(rcparams.params)

from scipy.optimize import minimize

# %%
# G/c**3 (s/kg)
conversion = 2.477e-36

# Solar mass (kg)
M_sun = 2e30

# %%
def fun(chi, Q_star, l, m, n):
    
    omega = qnm.omega(l, m, n, 1, chi)
    f = np.real(omega)/(2*np.pi)
    tau = -1/np.imag(omega)
    Q = np.pi*f*tau
    
    return abs(Q_star - Q)

# %%
# Base plot
# ---------

fig, ax = plt.subplots(figsize=(6,4), dpi=180)

chi_array = np.linspace(0, 0.99, 200)

for n in range(2):
    for l in range(2,4):
        
        if (l==3) & (n==1):
            pass
        
        else:
            for m in range(-l,l+1):
                
                # Evaluate the QNM frequencies
                frequencies = qnm.omega(l, m, n, 1, chi_array)
                        
                # Add to the figure
                ax.plot(
                    np.real(frequencies)/(2*np.pi), 
                    -np.imag(frequencies), 
                    c='C0'
                )

ax.set_xlabel('$M_ff_{\ell m n}$')
ax.set_ylabel('$M_f/ \\tau_{\ell m n}$')

ax.set_xlim(0)
ax.set_ylim(0)

# Add measurements
# ----------------

# The measured frequency and damping time
f_star = 200
tau_star = 0.007

# The quality factor
Q_star = np.pi*f_star*tau_star

# Add the line corresponding to the measurement
x = np.linspace(0, 1)
ax.plot(x, (np.pi/Q_star)*x, c='k')

# Identify points of intersection between the measurement and the Kerr 
# spectrum

intersected_modes = []
fitted_spins = []
fitted_masses = []

for n in range(2):
    for l in range(2,4):
        
        if (l==3) & (n==1):
            pass
        
        else:
            for m in range(-l,l+1):
                result = minimize(
                    fun, 
                    x0=0.5, 
                    args=(Q_star, l, m, n), 
                    bounds=[(0.,0.99)]
                )
                if result['fun']<1e-5:
                    
                    chi_fit = result['x'][0]
                    omega_fit = qnm.omega(l, m, n, 1, chi_fit)
                    
                    Mf_fit = (np.real(omega_fit)/(2*np.pi))/(f_star*conversion)
                    
                    intersected_modes.append((l,m,n))
                    fitted_spins.append(chi_fit)
                    fitted_masses.append(Mf_fit)
                    
                    ax.plot(
                        np.real(omega_fit)/(2*np.pi), 
                        -np.imag(omega_fit), 
                        'o', 
                        c='C3',
                        alpha=0.5
                    )
                    
print('Measurement compatible with modes:')
for mode, chi, Mf in zip(intersected_modes, fitted_spins, fitted_masses):
    print(f'{mode}, chi = {chi:.3f}, Mf = {Mf/M_sun:.3f} solar masses')
# Out:
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.949, Mf = 87.068 solar masses
# (2, 2, 0), chi = 0.853, Mf = 100.429 solar masses
# (3, 1, 0), chi = 0.818, Mf = 115.212 solar masses
# (3, 2, 0), chi = 0.674, Mf = 120.295 solar masses
# (3, 3, 0), chi = 0.563, Mf = 123.417 solar masses
# (2, 2, 1), chi = 0.987, Mf = 137.490 solar masses

# %%
def bh_spectroscopy(f_star, tau_star, plot=True, verbose=True):
    
    # The quality factor
    Q_star = np.pi*f_star*tau_star
    
    if plot:
        
        # Base plot
        # ---------

        fig, ax = plt.subplots(figsize=(6,4)) # , dpi=180)

        chi_array = np.linspace(0, 0.99, 200)

        for n in range(2):
            for l in range(2,4):

                if (l==3) & (n==1):
                    pass

                else:
                    for m in range(-l,l+1):

                        # Evaluate the QNM frequencies
                        frequencies = qnm.omega(l, m, n, 1, chi_array)

                        # Add to the figure
                        ax.plot(
                            np.real(frequencies)/(2*np.pi), 
                            -np.imag(frequencies), 
                            c='C0'
                        )

        ax.set_xlabel('$M_ff_{\ell m n}$')
        ax.set_ylabel('$M_f/ \\tau_{\ell m n}$')

        ax.set_xlim(0)
        ax.set_ylim(0)

        # Add measurements
        # ----------------

        # Add the line corresponding to the measurement
        x = np.linspace(0, 1)
        ax.plot(x, (np.pi/Q_star)*x, c='k')

    # Identify points of intersection between the measurement and the Kerr 
    # spectrum

    intersected_modes = []
    fitted_spins = []
    fitted_masses = []

    for n in range(2):
        for l in range(2,4):

            if (l==3) & (n==1):
                pass

            else:
                for m in range(-l,l+1):
                    result = minimize(
                        fun, 
                        x0=0.5, 
                        args=(Q_star, l, m, n), 
                        bounds=[(0.,0.99)]
                    )
                    if result['fun']<1e-5:

                        chi_fit = result['x'][0]
                        omega_fit = qnm.omega(l, m, n, 1, chi_fit)

                        Mf_fit = (np.real(omega_fit)/(2*np.pi))/(f_star*conversion)

                        intersected_modes.append((l,m,n))
                        fitted_spins.append(chi_fit)
                        fitted_masses.append(Mf_fit)
                        
                        if plot:
                            ax.plot(
                                np.real(omega_fit)/(2*np.pi), 
                                -np.imag(omega_fit), 
                                'o', 
                                c='C3',
                                alpha=0.5
                            )
    
    if verbose:
        print('Measurement compatible with modes:')
        for mode, chi, Mf in zip(intersected_modes, fitted_spins, fitted_masses):
            print(f'{mode}, chi = {chi:.3f}, Mf = {Mf/M_sun:.3f} solar masses')
        
    for mode, chi, Mf in zip(intersected_modes, fitted_spins, fitted_masses):
        if mode == (2,2,1):
            return (chi, Mf/M_sun)

# %%
_ = bh_spectroscopy(f_star = 200, tau_star = 0.007)

# %%
bh_spectroscopy(f_star = 300, tau_star = 0.001, plot=False)
# Out:
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.761, Mf = 48.825 solar masses
# (2, 2, 1), chi = 0.597, Mf = 51.281 solar masses
# (0.5973906423287315, 51.280993753972005)

# %%
f_array = np.linspace(200, 400)
tau_array = np.linspace(0.001, 0.01)

chi_target = 0.853
Mf_target = 100.429 

results = []

for f_star in f_array:
    for tau_star in tau_array:
        chi_Mf = bh_spectroscopy(f_star, tau_star, plot=False)
        if chi_Mf is not None:
            chi = chi_Mf[0]
            Mf = chi_Mf[1]
            diff = (chi-chi_target)**2 + (Mf-Mf_target)**2
            results.append((f_star, tau_star, diff))
# Out:
# Measurement compatible with modes:
# (2, -2, 1), chi = 0.016, Mf = 55.331 solar masses
# (2, -1, 1), chi = 0.032, Mf = 55.329 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.758, Mf = 60.785 solar masses
# (2, 1, 1), chi = 0.456, Mf = 63.313 solar masses
# (2, 2, 1), chi = 0.301, Mf = 64.037 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.940, Mf = 63.902 solar masses
# (2, 1, 1), chi = 0.671, Mf = 69.568 solar masses
# (2, 2, 1), chi = 0.499, Mf = 71.835 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.787, Mf = 74.482 solar masses
# (2, 2, 1), chi = 0.628, Mf = 78.761 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.856, Mf = 78.303 solar masses
# (2, 2, 1), chi = 0.715, Mf = 84.874 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.900, Mf = 81.244 solar masses
# (2, 2, 1), chi = 0.775, Mf = 90.251 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.928, Mf = 83.486 solar masses
# (2, 2, 1), chi = 0.819, Mf = 94.979 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.948, Mf = 85.172 solar masses
# (2, 2, 1), chi = 0.851, Mf = 99.148 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.961, Mf = 86.413 solar masses
# (2, 2, 1), chi = 0.875, Mf = 102.839 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.959, Mf = 47.198 solar masses
# (2, 1, 1), chi = 0.971, Mf = 87.292 solar masses
# (2, 2, 1), chi = 0.894, Mf = 106.122 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.599, Mf = 50.902 solar masses
# (2, 1, 1), chi = 0.978, Mf = 87.869 solar masses
# (2, 2, 1), chi = 0.909, Mf = 109.058 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.331, Mf = 54.368 solar masses
# (2, 1, 1), chi = 0.984, Mf = 88.178 solar masses
# (2, 2, 1), chi = 0.921, Mf = 111.698 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.126, Mf = 57.652 solar masses
# (2, -1, 0), chi = 0.333, Mf = 57.357 solar masses
# (2, 1, 1), chi = 0.988, Mf = 88.223 solar masses
# (2, 2, 1), chi = 0.931, Mf = 114.084 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.278, Mf = 60.481 solar masses
# (2, 1, 0), chi = 0.070, Mf = 60.767 solar masses
# (2, 2, 0), chi = 0.037, Mf = 60.781 solar masses
# (2, 2, 1), chi = 0.939, Mf = 116.249 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.580, Mf = 62.169 solar masses
# (2, 1, 0), chi = 0.280, Mf = 63.519 solar masses
# (2, 2, 0), chi = 0.167, Mf = 63.771 solar masses
# (2, 2, 1), chi = 0.946, Mf = 118.222 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.727, Mf = 63.616 solar masses
# (2, 1, 0), chi = 0.423, Mf = 65.976 solar masses
# (2, 2, 0), chi = 0.274, Mf = 66.629 solar masses
# (2, 2, 1), chi = 0.951, Mf = 120.029 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.820, Mf = 64.850 solar masses
# (2, 1, 0), chi = 0.528, Mf = 68.206 solar masses
# (2, 2, 0), chi = 0.362, Mf = 69.361 solar masses
# (2, 2, 1), chi = 0.956, Mf = 121.688 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.884, Mf = 65.899 solar masses
# (2, 1, 0), chi = 0.608, Mf = 70.242 solar masses
# (2, 2, 0), chi = 0.436, Mf = 71.972 solar masses
# (3, -3, 0), chi = 0.907, Mf = 75.944 solar masses
# (2, 2, 1), chi = 0.960, Mf = 123.218 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.931, Mf = 66.788 solar masses
# (2, 1, 0), chi = 0.670, Mf = 72.104 solar masses
# (2, 2, 0), chi = 0.498, Mf = 74.466 solar masses
# (3, -3, 0), chi = 0.671, Mf = 79.985 solar masses
# (2, 2, 1), chi = 0.964, Mf = 124.633 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.967, Mf = 67.539 solar masses
# (2, 1, 0), chi = 0.720, Mf = 73.810 solar masses
# (2, 2, 0), chi = 0.551, Mf = 76.847 solar masses
# (3, -3, 0), chi = 0.476, Mf = 83.837 solar masses
# (2, 2, 1), chi = 0.967, Mf = 125.945 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.760, Mf = 75.373 solar masses
# (2, 2, 0), chi = 0.596, Mf = 79.119 solar masses
# (3, -3, 0), chi = 0.314, Mf = 87.518 solar masses
# (3, -2, 0), chi = 0.612, Mf = 86.406 solar masses
# (2, 2, 1), chi = 0.970, Mf = 127.165 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.793, Mf = 76.807 solar masses
# (2, 2, 0), chi = 0.634, Mf = 81.287 solar masses
# (3, -3, 0), chi = 0.177, Mf = 91.042 solar masses
# (3, -2, 0), chi = 0.296, Mf = 90.777 solar masses
# (2, 2, 1), chi = 0.972, Mf = 128.302 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.820, Mf = 78.123 solar masses
# (2, 2, 0), chi = 0.668, Mf = 83.355 solar masses
# (3, -3, 0), chi = 0.059, Mf = 94.422 solar masses
# (3, -2, 0), chi = 0.092, Mf = 94.395 solar masses
# (3, -1, 0), chi = 0.578, Mf = 92.551 solar masses
# (2, 2, 1), chi = 0.974, Mf = 129.365 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.843, Mf = 79.331 solar masses
# (2, 2, 0), chi = 0.697, Mf = 85.329 solar masses
# (3, -1, 0), chi = 0.875, Mf = 92.440 solar masses
# (3, 1, 0), chi = 0.111, Mf = 97.598 solar masses
# (3, 2, 0), chi = 0.061, Mf = 97.653 solar masses
# (3, 3, 0), chi = 0.041, Mf = 97.666 solar masses
# (2, 2, 1), chi = 0.976, Mf = 130.361 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.862, Mf = 80.442 solar masses
# (2, 2, 0), chi = 0.722, Mf = 87.213 solar masses
# (3, 0, 0), chi = 0.539, Mf = 98.681 solar masses
# (3, 1, 0), chi = 0.291, Mf = 100.274 solar masses
# (3, 2, 0), chi = 0.182, Mf = 100.661 solar masses
# (3, 3, 0), chi = 0.129, Mf = 100.783 solar masses
# (2, 2, 1), chi = 0.978, Mf = 131.295 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.879, Mf = 81.464 solar masses
# (2, 2, 0), chi = 0.745, Mf = 89.011 solar masses
# (3, 0, 0), chi = 0.668, Mf = 100.138 solar masses
# (3, 1, 0), chi = 0.416, Mf = 102.635 solar masses
# (3, 2, 0), chi = 0.280, Mf = 103.468 solar masses
# (3, 3, 0), chi = 0.205, Mf = 103.781 solar masses
# (2, 2, 1), chi = 0.979, Mf = 132.173 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.893, Mf = 82.405 solar masses
# (2, 2, 0), chi = 0.765, Mf = 90.729 solar masses
# (3, 0, 0), chi = 0.757, Mf = 101.437 solar masses
# (3, 1, 0), chi = 0.511, Mf = 104.772 solar masses
# (3, 2, 0), chi = 0.362, Mf = 106.102 solar masses
# (3, 3, 0), chi = 0.272, Mf = 106.667 solar masses
# (2, 2, 1), chi = 0.981, Mf = 133.001 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.905, Mf = 83.271 solar masses
# (2, 2, 0), chi = 0.782, Mf = 92.370 solar masses
# (3, 0, 0), chi = 0.823, Mf = 102.597 solar masses
# (3, 1, 0), chi = 0.585, Mf = 106.725 solar masses
# (3, 2, 0), chi = 0.430, Mf = 108.582 solar masses
# (3, 3, 0), chi = 0.331, Mf = 109.445 solar masses
# (2, 2, 1), chi = 0.982, Mf = 133.782 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.915, Mf = 84.071 solar masses
# (2, 2, 0), chi = 0.798, Mf = 93.940 solar masses
# (3, 0, 0), chi = 0.875, Mf = 103.631 solar masses
# (3, 1, 0), chi = 0.646, Mf = 108.518 solar masses
# (3, 2, 0), chi = 0.489, Mf = 110.922 solar masses
# (3, 3, 0), chi = 0.383, Mf = 112.123 solar masses
# (2, 2, 1), chi = 0.983, Mf = 134.520 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.924, Mf = 84.809 solar masses
# (2, 2, 0), chi = 0.812, Mf = 95.442 solar masses
# (3, 0, 0), chi = 0.915, Mf = 104.554 solar masses
# (3, 1, 0), chi = 0.695, Mf = 110.169 solar masses
# (3, 2, 0), chi = 0.539, Mf = 113.135 solar masses
# (3, 3, 0), chi = 0.430, Mf = 114.704 solar masses
# (2, 2, 1), chi = 0.984, Mf = 135.219 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.932, Mf = 85.490 solar masses
# (2, 2, 0), chi = 0.825, Mf = 96.880 solar masses
# (3, 0, 0), chi = 0.948, Mf = 105.379 solar masses
# (3, 1, 0), chi = 0.736, Mf = 111.692 solar masses
# (3, 2, 0), chi = 0.583, Mf = 115.229 solar masses
# (3, 3, 0), chi = 0.471, Mf = 117.193 solar masses
# (2, 2, 1), chi = 0.985, Mf = 135.881 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.939, Mf = 86.121 solar masses
# (2, 2, 0), chi = 0.836, Mf = 98.257 solar masses
# (3, 0, 0), chi = 0.975, Mf = 106.115 solar masses
# (3, 1, 0), chi = 0.771, Mf = 113.098 solar masses
# (3, 2, 0), chi = 0.621, Mf = 117.213 solar masses
# (3, 3, 0), chi = 0.509, Mf = 119.596 solar masses
# (2, 2, 1), chi = 0.986, Mf = 136.510 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.945, Mf = 86.704 solar masses
# (2, 2, 0), chi = 0.847, Mf = 99.578 solar masses
# (3, 1, 0), chi = 0.800, Mf = 114.399 solar masses
# (3, 2, 0), chi = 0.654, Mf = 119.095 solar masses
# (3, 3, 0), chi = 0.542, Mf = 121.915 solar masses
# (2, 2, 1), chi = 0.987, Mf = 137.107 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.951, Mf = 87.244 solar masses
# (2, 2, 0), chi = 0.856, Mf = 100.845 solar masses
# (3, 1, 0), chi = 0.826, Mf = 115.603 solar masses
# (3, 2, 0), chi = 0.683, Mf = 120.880 solar masses
# (3, 3, 0), chi = 0.573, Mf = 124.155 solar masses
# (2, 2, 1), chi = 0.987, Mf = 137.676 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.956, Mf = 87.744 solar masses
# (2, 2, 0), chi = 0.865, Mf = 102.062 solar masses
# (3, 1, 0), chi = 0.847, Mf = 116.717 solar masses
# (3, 2, 0), chi = 0.709, Mf = 122.576 solar masses
# (3, 3, 0), chi = 0.600, Mf = 126.319 solar masses
# (2, 2, 1), chi = 0.988, Mf = 138.218 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.960, Mf = 88.208 solar masses
# (2, 2, 0), chi = 0.872, Mf = 103.231 solar masses
# (3, 1, 0), chi = 0.866, Mf = 117.751 solar masses
# (3, 2, 0), chi = 0.733, Mf = 124.187 solar masses
# (3, 3, 0), chi = 0.625, Mf = 128.411 solar masses
# (2, 2, 1), chi = 0.989, Mf = 138.735 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.964, Mf = 88.639 solar masses
# (2, 2, 0), chi = 0.880, Mf = 104.355 solar masses
# (3, 1, 0), chi = 0.883, Mf = 118.709 solar masses
# (3, 2, 0), chi = 0.753, Mf = 125.719 solar masses
# (3, 3, 0), chi = 0.648, Mf = 130.434 solar masses
# (2, 2, 1), chi = 0.989, Mf = 139.229 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.967, Mf = 89.039 solar masses
# (2, 2, 0), chi = 0.886, Mf = 105.436 solar masses
# (3, 1, 0), chi = 0.898, Mf = 119.598 solar masses
# (3, 2, 0), chi = 0.772, Mf = 127.177 solar masses
# (3, 3, 0), chi = 0.669, Mf = 132.391 solar masses
# (2, 2, 1), chi = 0.990, Mf = 139.701 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.970, Mf = 89.410 solar masses
# (2, 2, 0), chi = 0.892, Mf = 106.478 solar masses
# (3, 1, 0), chi = 0.910, Mf = 120.424 solar masses
# (3, 2, 0), chi = 0.788, Mf = 128.565 solar masses
# (3, 3, 0), chi = 0.688, Mf = 134.285 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.973, Mf = 89.756 solar masses
# (2, 2, 0), chi = 0.898, Mf = 107.481 solar masses
# (3, 1, 0), chi = 0.922, Mf = 121.191 solar masses
# (3, 2, 0), chi = 0.803, Mf = 129.887 solar masses
# (3, 3, 0), chi = 0.706, Mf = 136.118 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.976, Mf = 90.077 solar masses
# (2, 2, 0), chi = 0.903, Mf = 108.448 solar masses
# (3, 1, 0), chi = 0.932, Mf = 121.904 solar masses
# (3, 2, 0), chi = 0.817, Mf = 131.147 solar masses
# (3, 3, 0), chi = 0.722, Mf = 137.894 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.978, Mf = 90.375 solar masses
# (2, 2, 0), chi = 0.908, Mf = 109.380 solar masses
# (3, 1, 0), chi = 0.941, Mf = 122.566 solar masses
# (3, 2, 0), chi = 0.829, Mf = 132.348 solar masses
# (3, 3, 0), chi = 0.737, Mf = 139.614 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.980, Mf = 90.653 solar masses
# (2, 2, 0), chi = 0.912, Mf = 110.280 solar masses
# (3, 1, 0), chi = 0.949, Mf = 123.183 solar masses
# (3, 2, 0), chi = 0.840, Mf = 133.495 solar masses
# (3, 3, 0), chi = 0.750, Mf = 141.281 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.982, Mf = 90.911 solar masses
# (2, 2, 0), chi = 0.916, Mf = 111.150 solar masses
# (3, 1, 0), chi = 0.956, Mf = 123.757 solar masses
# (3, 2, 0), chi = 0.851, Mf = 134.590 solar masses
# (3, 3, 0), chi = 0.763, Mf = 142.898 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.984, Mf = 91.152 solar masses
# (2, 2, 0), chi = 0.920, Mf = 111.990 solar masses
# (3, 1, 0), chi = 0.962, Mf = 124.292 solar masses
# (3, 2, 0), chi = 0.860, Mf = 135.636 solar masses
# (3, 3, 0), chi = 0.775, Mf = 144.466 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.986, Mf = 91.375 solar masses
# (2, 2, 0), chi = 0.924, Mf = 112.802 solar masses
# (3, 1, 0), chi = 0.968, Mf = 124.790 solar masses
# (3, 2, 0), chi = 0.868, Mf = 136.635 solar masses
# (3, 3, 0), chi = 0.786, Mf = 145.987 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.987, Mf = 91.584 solar masses
# (2, 2, 0), chi = 0.927, Mf = 113.588 solar masses
# (3, 1, 0), chi = 0.974, Mf = 125.255 solar masses
# (3, 2, 0), chi = 0.876, Mf = 137.591 solar masses
# (3, 3, 0), chi = 0.796, Mf = 147.463 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.988, Mf = 91.777 solar masses
# (2, 2, 0), chi = 0.930, Mf = 114.349 solar masses
# (3, 1, 0), chi = 0.978, Mf = 125.688 solar masses
# (3, 2, 0), chi = 0.883, Mf = 138.506 solar masses
# (3, 3, 0), chi = 0.805, Mf = 148.896 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.990, Mf = 91.958 solar masses
# (2, 2, 0), chi = 0.933, Mf = 115.085 solar masses
# (3, 1, 0), chi = 0.983, Mf = 126.092 solar masses
# (3, 2, 0), chi = 0.890, Mf = 139.381 solar masses
# (3, 3, 0), chi = 0.814, Mf = 150.288 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.936, Mf = 115.799 solar masses
# (3, 1, 0), chi = 0.987, Mf = 126.469 solar masses
# (3, 2, 0), chi = 0.896, Mf = 140.219 solar masses
# (3, 3, 0), chi = 0.822, Mf = 151.641 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.241, Mf = 55.024 solar masses
# (2, 1, 1), chi = 0.053, Mf = 55.210 solar masses
# (2, 2, 1), chi = 0.028, Mf = 55.217 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.792, Mf = 60.093 solar masses
# (2, 1, 1), chi = 0.493, Mf = 62.938 solar masses
# (2, 2, 1), chi = 0.333, Mf = 63.811 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.958, Mf = 62.902 solar masses
# (2, 1, 1), chi = 0.693, Mf = 68.986 solar masses
# (2, 2, 1), chi = 0.522, Mf = 71.483 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.802, Mf = 73.708 solar masses
# (2, 2, 1), chi = 0.645, Mf = 78.273 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.866, Mf = 77.353 solar masses
# (2, 2, 1), chi = 0.728, Mf = 84.246 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.907, Mf = 80.139 solar masses
# (2, 2, 1), chi = 0.786, Mf = 89.484 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.933, Mf = 82.246 solar masses
# (2, 2, 1), chi = 0.827, Mf = 94.080 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.952, Mf = 83.815 solar masses
# (2, 2, 1), chi = 0.858, Mf = 98.125 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.964, Mf = 84.954 solar masses
# (2, 2, 1), chi = 0.881, Mf = 101.702 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.840, Mf = 47.353 solar masses
# (2, 1, 1), chi = 0.973, Mf = 85.742 solar masses
# (2, 2, 1), chi = 0.899, Mf = 104.881 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.506, Mf = 50.976 solar masses
# (2, 1, 1), chi = 0.980, Mf = 86.234 solar masses
# (2, 2, 1), chi = 0.913, Mf = 107.722 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.257, Mf = 54.379 solar masses
# (2, 1, 1), chi = 0.985, Mf = 86.459 solar masses
# (2, 2, 1), chi = 0.924, Mf = 110.275 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.064, Mf = 57.607 solar masses
# (2, -1, 0), chi = 0.142, Mf = 57.555 solar masses
# (2, 1, 1), chi = 0.989, Mf = 86.406 solar masses
# (2, 2, 1), chi = 0.934, Mf = 112.580 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.430, Mf = 59.924 solar masses
# (2, 1, 0), chi = 0.160, Mf = 60.609 solar masses
# (2, 2, 0), chi = 0.089, Mf = 60.684 solar masses
# (2, 2, 1), chi = 0.942, Mf = 114.672 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.648, Mf = 61.515 solar masses
# (2, 1, 0), chi = 0.343, Mf = 63.234 solar masses
# (2, 2, 0), chi = 0.212, Mf = 63.622 solar masses
# (2, 2, 1), chi = 0.948, Mf = 116.579 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.770, Mf = 62.872 solar masses
# (2, 1, 0), chi = 0.471, Mf = 65.593 solar masses
# (2, 2, 0), chi = 0.313, Mf = 66.428 solar masses
# (2, 2, 1), chi = 0.953, Mf = 118.323 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.851, Mf = 64.024 solar masses
# (2, 1, 0), chi = 0.565, Mf = 67.738 solar masses
# (2, 2, 0), chi = 0.396, Mf = 69.108 solar masses
# (2, 2, 1), chi = 0.958, Mf = 119.925 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.908, Mf = 64.998 solar masses
# (2, 1, 0), chi = 0.638, Mf = 69.693 solar masses
# (2, 2, 0), chi = 0.466, Mf = 71.666 solar masses
# (3, -3, 0), chi = 0.793, Mf = 76.263 solar masses
# (2, 2, 1), chi = 0.962, Mf = 121.402 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.950, Mf = 65.820 solar masses
# (2, 1, 0), chi = 0.695, Mf = 71.480 solar masses
# (2, 2, 0), chi = 0.524, Mf = 74.106 solar masses
# (3, -3, 0), chi = 0.573, Mf = 80.213 solar masses
# (2, 2, 1), chi = 0.965, Mf = 122.767 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.982, Mf = 66.511 solar masses
# (2, 1, 0), chi = 0.741, Mf = 73.115 solar masses
# (2, 2, 0), chi = 0.574, Mf = 76.434 solar masses
# (3, -3, 0), chi = 0.392, Mf = 83.980 solar masses
# (2, 2, 1), chi = 0.968, Mf = 124.033 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.778, Mf = 74.611 solar masses
# (2, 2, 0), chi = 0.616, Mf = 78.652 solar masses
# (3, -3, 0), chi = 0.240, Mf = 87.580 solar masses
# (3, -2, 0), chi = 0.426, Mf = 87.051 solar masses
# (2, 2, 1), chi = 0.971, Mf = 125.210 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.808, Mf = 75.981 solar masses
# (2, 2, 0), chi = 0.653, Mf = 80.767 solar masses
# (3, -3, 0), chi = 0.111, Mf = 91.026 solar masses
# (3, -2, 0), chi = 0.178, Mf = 90.929 solar masses
# (2, 2, 1), chi = 0.973, Mf = 126.307 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.833, Mf = 77.236 solar masses
# (2, 2, 0), chi = 0.685, Mf = 82.783 solar masses
# (3, -3, 0), chi = 0.001, Mf = 94.330 solar masses
# (3, -2, 0), chi = 0.002, Mf = 94.330 solar masses
# (3, -1, 0), chi = 0.787, Mf = 90.489 solar masses
# (2, 2, 1), chi = 0.975, Mf = 127.332 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.855, Mf = 78.388 solar masses
# (2, 2, 0), chi = 0.712, Mf = 84.705 solar masses
# (3, -1, 0), chi = 0.959, Mf = 90.802 solar masses
# (3, 0, 0), chi = 0.463, Mf = 96.059 solar masses
# (3, 1, 0), chi = 0.224, Mf = 97.215 solar masses
# (3, 2, 0), chi = 0.134, Mf = 97.437 solar masses
# (3, 3, 0), chi = 0.094, Mf = 97.501 solar masses
# (2, 2, 1), chi = 0.977, Mf = 128.292 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.872, Mf = 79.445 solar masses
# (2, 2, 0), chi = 0.736, Mf = 86.537 solar masses
# (3, 0, 0), chi = 0.623, Mf = 97.585 solar masses
# (3, 1, 0), chi = 0.371, Mf = 99.688 solar masses
# (3, 2, 0), chi = 0.243, Mf = 100.322 solar masses
# (3, 3, 0), chi = 0.176, Mf = 100.547 solar masses
# (2, 2, 1), chi = 0.979, Mf = 129.193 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.888, Mf = 80.416 solar masses
# (2, 2, 0), chi = 0.757, Mf = 88.286 solar masses
# (3, 0, 0), chi = 0.727, Mf = 98.943 solar masses
# (3, 1, 0), chi = 0.478, Mf = 101.907 solar masses
# (3, 2, 0), chi = 0.332, Mf = 103.021 solar masses
# (3, 3, 0), chi = 0.248, Mf = 103.475 solar masses
# (2, 2, 1), chi = 0.980, Mf = 130.039 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.900, Mf = 81.310 solar masses
# (2, 2, 0), chi = 0.776, Mf = 89.955 solar masses
# (3, 0, 0), chi = 0.802, Mf = 100.152 solar masses
# (3, 1, 0), chi = 0.561, Mf = 103.924 solar masses
# (3, 2, 0), chi = 0.407, Mf = 105.556 solar masses
# (3, 3, 0), chi = 0.311, Mf = 106.293 solar masses
# (2, 2, 1), chi = 0.982, Mf = 130.837 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.912, Mf = 82.132 solar masses
# (2, 2, 0), chi = 0.793, Mf = 91.549 solar masses
# (3, 0, 0), chi = 0.859, Mf = 101.229 solar masses
# (3, 1, 0), chi = 0.627, Mf = 105.770 solar masses
# (3, 2, 0), chi = 0.470, Mf = 107.943 solar masses
# (3, 3, 0), chi = 0.366, Mf = 109.005 solar masses
# (2, 2, 1), chi = 0.983, Mf = 131.590 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.921, Mf = 82.889 solar masses
# (2, 2, 0), chi = 0.808, Mf = 93.073 solar masses
# (3, 0, 0), chi = 0.903, Mf = 102.187 solar masses
# (3, 1, 0), chi = 0.680, Mf = 107.466 solar masses
# (3, 2, 0), chi = 0.524, Mf = 110.197 solar masses
# (3, 3, 0), chi = 0.416, Mf = 111.617 solar masses
# (2, 2, 1), chi = 0.984, Mf = 132.301 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.930, Mf = 83.588 solar masses
# (2, 2, 0), chi = 0.821, Mf = 94.530 solar masses
# (3, 0, 0), chi = 0.939, Mf = 103.041 solar masses
# (3, 1, 0), chi = 0.725, Mf = 109.027 solar masses
# (3, 2, 0), chi = 0.571, Mf = 112.326 solar masses
# (3, 3, 0), chi = 0.460, Mf = 114.134 solar masses
# (2, 2, 1), chi = 0.985, Mf = 132.974 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.937, Mf = 84.232 solar masses
# (2, 2, 0), chi = 0.833, Mf = 95.924 solar masses
# (3, 0, 0), chi = 0.968, Mf = 103.801 solar masses
# (3, 1, 0), chi = 0.762, Mf = 110.466 solar masses
# (3, 2, 0), chi = 0.611, Mf = 114.341 solar masses
# (3, 3, 0), chi = 0.499, Mf = 116.561 solar masses
# (2, 2, 1), chi = 0.986, Mf = 133.612 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.944, Mf = 84.827 solar masses
# (2, 2, 0), chi = 0.844, Mf = 97.260 solar masses
# (3, 1, 0), chi = 0.793, Mf = 111.794 solar masses
# (3, 2, 0), chi = 0.646, Mf = 116.249 solar masses
# (3, 3, 0), chi = 0.534, Mf = 118.902 solar masses
# (2, 2, 1), chi = 0.987, Mf = 134.218 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.949, Mf = 85.378 solar masses
# (2, 2, 0), chi = 0.854, Mf = 98.540 solar masses
# (3, 1, 0), chi = 0.820, Mf = 113.021 solar masses
# (3, 2, 0), chi = 0.677, Mf = 118.058 solar masses
# (3, 3, 0), chi = 0.566, Mf = 121.161 solar masses
# (2, 2, 1), chi = 0.987, Mf = 134.794 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.955, Mf = 85.887 solar masses
# (2, 2, 0), chi = 0.863, Mf = 99.768 solar masses
# (3, 1, 0), chi = 0.843, Mf = 114.155 solar masses
# (3, 2, 0), chi = 0.704, Mf = 119.773 solar masses
# (3, 3, 0), chi = 0.595, Mf = 123.342 solar masses
# (2, 2, 1), chi = 0.988, Mf = 135.341 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.959, Mf = 86.358 solar masses
# (2, 2, 0), chi = 0.871, Mf = 100.947 solar masses
# (3, 1, 0), chi = 0.863, Mf = 115.204 solar masses
# (3, 2, 0), chi = 0.728, Mf = 121.401 solar masses
# (3, 3, 0), chi = 0.621, Mf = 125.448 solar masses
# (2, 2, 1), chi = 0.989, Mf = 135.863 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.963, Mf = 86.795 solar masses
# (2, 2, 0), chi = 0.878, Mf = 102.079 solar masses
# (3, 1, 0), chi = 0.880, Mf = 116.176 solar masses
# (3, 2, 0), chi = 0.750, Mf = 122.948 solar masses
# (3, 3, 0), chi = 0.644, Mf = 127.484 solar masses
# (2, 2, 1), chi = 0.989, Mf = 136.361 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.967, Mf = 87.200 solar masses
# (2, 2, 0), chi = 0.885, Mf = 103.167 solar masses
# (3, 1, 0), chi = 0.895, Mf = 117.076 solar masses
# (3, 2, 0), chi = 0.769, Mf = 124.417 solar masses
# (3, 3, 0), chi = 0.666, Mf = 129.452 solar masses
# (2, 2, 1), chi = 0.990, Mf = 136.837 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.970, Mf = 87.575 solar masses
# (2, 2, 0), chi = 0.891, Mf = 104.214 solar masses
# (3, 1, 0), chi = 0.909, Mf = 117.910 solar masses
# (3, 2, 0), chi = 0.786, Mf = 125.815 solar masses
# (3, 3, 0), chi = 0.686, Mf = 131.354 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.973, Mf = 87.923 solar masses
# (2, 2, 0), chi = 0.897, Mf = 105.221 solar masses
# (3, 1, 0), chi = 0.920, Mf = 118.684 solar masses
# (3, 2, 0), chi = 0.802, Mf = 127.145 solar masses
# (3, 3, 0), chi = 0.704, Mf = 133.195 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.976, Mf = 88.247 solar masses
# (2, 2, 0), chi = 0.903, Mf = 106.192 solar masses
# (3, 1, 0), chi = 0.931, Mf = 119.403 solar masses
# (3, 2, 0), chi = 0.816, Mf = 128.411 solar masses
# (3, 3, 0), chi = 0.720, Mf = 134.977 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.978, Mf = 88.547 solar masses
# (2, 2, 0), chi = 0.907, Mf = 107.127 solar masses
# (3, 1, 0), chi = 0.940, Mf = 120.070 solar masses
# (3, 2, 0), chi = 0.828, Mf = 129.618 solar masses
# (3, 3, 0), chi = 0.736, Mf = 136.701 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.980, Mf = 88.826 solar masses
# (2, 2, 0), chi = 0.912, Mf = 108.030 solar masses
# (3, 1, 0), chi = 0.948, Mf = 120.689 solar masses
# (3, 2, 0), chi = 0.840, Mf = 130.768 solar masses
# (3, 3, 0), chi = 0.750, Mf = 138.372 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.982, Mf = 89.085 solar masses
# (2, 2, 0), chi = 0.916, Mf = 108.900 solar masses
# (3, 1, 0), chi = 0.956, Mf = 121.265 solar masses
# (3, 2, 0), chi = 0.850, Mf = 131.865 solar masses
# (3, 3, 0), chi = 0.763, Mf = 139.990 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.984, Mf = 89.326 solar masses
# (2, 2, 0), chi = 0.920, Mf = 109.741 solar masses
# (3, 1, 0), chi = 0.962, Mf = 121.800 solar masses
# (3, 2, 0), chi = 0.860, Mf = 132.912 solar masses
# (3, 3, 0), chi = 0.775, Mf = 141.559 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.986, Mf = 89.550 solar masses
# (2, 2, 0), chi = 0.924, Mf = 110.553 solar masses
# (3, 1, 0), chi = 0.968, Mf = 122.299 solar masses
# (3, 2, 0), chi = 0.868, Mf = 133.911 solar masses
# (3, 3, 0), chi = 0.786, Mf = 143.080 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.987, Mf = 89.758 solar masses
# (2, 2, 0), chi = 0.927, Mf = 111.339 solar masses
# (3, 1, 0), chi = 0.974, Mf = 122.762 solar masses
# (3, 2, 0), chi = 0.876, Mf = 134.866 solar masses
# (3, 3, 0), chi = 0.796, Mf = 144.556 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.988, Mf = 89.951 solar masses
# (2, 2, 0), chi = 0.930, Mf = 112.098 solar masses
# (3, 1, 0), chi = 0.979, Mf = 123.194 solar masses
# (3, 2, 0), chi = 0.884, Mf = 135.779 solar masses
# (3, 3, 0), chi = 0.806, Mf = 145.987 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.990, Mf = 90.131 solar masses
# (2, 2, 0), chi = 0.933, Mf = 112.833 solar masses
# (3, 1, 0), chi = 0.983, Mf = 123.597 solar masses
# (3, 2, 0), chi = 0.891, Mf = 136.652 solar masses
# (3, 3, 0), chi = 0.815, Mf = 147.377 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.936, Mf = 113.545 solar masses
# (3, 1, 0), chi = 0.987, Mf = 123.972 solar masses
# (3, 2, 0), chi = 0.897, Mf = 137.488 solar masses
# (3, 3, 0), chi = 0.823, Mf = 148.726 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.939, Mf = 114.235 solar masses
# (3, 2, 0), chi = 0.903, Mf = 138.288 solar masses
# (3, 3, 0), chi = 0.831, Mf = 150.037 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.377, Mf = 54.599 solar masses
# (2, 1, 1), chi = 0.127, Mf = 55.057 solar masses
# (2, 2, 1), chi = 0.069, Mf = 55.097 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.822, Mf = 59.391 solar masses
# (2, 1, 1), chi = 0.527, Mf = 62.550 solar masses
# (2, 2, 1), chi = 0.362, Mf = 63.580 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.975, Mf = 61.893 solar masses
# (2, 1, 1), chi = 0.713, Mf = 68.399 solar masses
# (2, 2, 1), chi = 0.544, Mf = 71.126 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.815, Mf = 72.934 solar masses
# (2, 2, 1), chi = 0.662, Mf = 77.781 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.875, Mf = 76.411 solar masses
# (2, 2, 1), chi = 0.741, Mf = 83.616 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.913, Mf = 79.049 solar masses
# (2, 2, 1), chi = 0.795, Mf = 88.719 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.938, Mf = 81.028 solar masses
# (2, 2, 1), chi = 0.835, Mf = 93.187 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.955, Mf = 82.485 solar masses
# (2, 2, 1), chi = 0.864, Mf = 97.114 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.967, Mf = 83.527 solar masses
# (2, 2, 1), chi = 0.886, Mf = 100.581 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.733, Mf = 47.477 solar masses
# (2, 1, 1), chi = 0.976, Mf = 84.228 solar masses
# (2, 2, 1), chi = 0.903, Mf = 103.661 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.422, Mf = 51.028 solar masses
# (2, 1, 1), chi = 0.982, Mf = 84.639 solar masses
# (2, 2, 1), chi = 0.917, Mf = 106.411 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.188, Mf = 54.371 solar masses
# (2, 1, 1), chi = 0.987, Mf = 84.779 solar masses
# (2, 2, 1), chi = 0.928, Mf = 108.881 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.006, Mf = 57.546 solar masses
# (2, -1, 0), chi = 0.013, Mf = 57.546 solar masses
# (2, 2, 1), chi = 0.937, Mf = 111.111 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.529, Mf = 59.353 solar masses
# (2, 1, 0), chi = 0.236, Mf = 60.406 solar masses
# (2, 2, 0), chi = 0.138, Mf = 60.572 solar masses
# (2, 2, 1), chi = 0.944, Mf = 113.133 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.702, Mf = 60.852 solar masses
# (2, 1, 0), chi = 0.398, Mf = 62.921 solar masses
# (2, 2, 0), chi = 0.254, Mf = 63.459 solar masses
# (2, 2, 1), chi = 0.950, Mf = 114.976 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.807, Mf = 62.124 solar masses
# (2, 1, 0), chi = 0.513, Mf = 65.191 solar masses
# (2, 2, 0), chi = 0.349, Mf = 66.214 solar masses
# (2, 2, 1), chi = 0.955, Mf = 116.661 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.877, Mf = 63.198 solar masses
# (2, 1, 0), chi = 0.599, Mf = 67.253 solar masses
# (2, 2, 0), chi = 0.427, Mf = 68.843 solar masses
# (3, -3, 0), chi = 0.940, Mf = 72.468 solar masses
# (2, 2, 1), chi = 0.960, Mf = 118.209 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.928, Mf = 64.102 solar masses
# (2, 1, 0), chi = 0.665, Mf = 69.133 solar masses
# (2, 2, 0), chi = 0.493, Mf = 71.349 solar masses
# (3, -3, 0), chi = 0.689, Mf = 76.530 solar masses
# (2, 2, 1), chi = 0.964, Mf = 119.635 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.966, Mf = 64.862 solar masses
# (2, 1, 0), chi = 0.718, Mf = 70.848 solar masses
# (2, 2, 0), chi = 0.548, Mf = 73.737 solar masses
# (3, -3, 0), chi = 0.484, Mf = 80.393 solar masses
# (2, 2, 1), chi = 0.967, Mf = 120.953 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.760, Mf = 72.414 solar masses
# (2, 2, 0), chi = 0.595, Mf = 76.011 solar masses
# (3, -3, 0), chi = 0.314, Mf = 84.078 solar masses
# (3, -2, 0), chi = 0.613, Mf = 83.006 solar masses
# (2, 2, 1), chi = 0.970, Mf = 122.175 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.794, Mf = 73.846 solar masses
# (2, 2, 0), chi = 0.636, Mf = 78.178 solar masses
# (3, -3, 0), chi = 0.172, Mf = 87.600 solar masses
# (3, -2, 0), chi = 0.287, Mf = 87.360 solar masses
# (2, 2, 1), chi = 0.972, Mf = 123.311 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.822, Mf = 75.155 solar masses
# (2, 2, 0), chi = 0.670, Mf = 80.240 solar masses
# (3, -3, 0), chi = 0.051, Mf = 90.971 solar masses
# (3, -2, 0), chi = 0.078, Mf = 90.952 solar masses
# (3, -1, 0), chi = 0.625, Mf = 88.824 solar masses
# (2, 2, 1), chi = 0.974, Mf = 124.370 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.845, Mf = 76.353 solar masses
# (2, 2, 0), chi = 0.700, Mf = 82.205 solar masses
# (3, -1, 0), chi = 0.895, Mf = 88.854 solar masses
# (3, 1, 0), chi = 0.137, Mf = 94.102 solar masses
# (3, 2, 0), chi = 0.077, Mf = 94.182 solar masses
# (3, 3, 0), chi = 0.053, Mf = 94.202 solar masses
# (2, 2, 1), chi = 0.976, Mf = 125.359 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.865, Mf = 77.451 solar masses
# (2, 2, 0), chi = 0.726, Mf = 84.076 solar masses
# (3, 0, 0), chi = 0.564, Mf = 95.047 solar masses
# (3, 1, 0), chi = 0.314, Mf = 96.724 solar masses
# (3, 2, 0), chi = 0.199, Mf = 97.160 solar masses
# (3, 3, 0), chi = 0.142, Mf = 97.302 solar masses
# (2, 2, 1), chi = 0.978, Mf = 126.285 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.882, Mf = 78.458 solar masses
# (2, 2, 0), chi = 0.749, Mf = 85.860 solar masses
# (3, 0, 0), chi = 0.688, Mf = 96.474 solar masses
# (3, 1, 0), chi = 0.437, Mf = 99.040 solar masses
# (3, 2, 0), chi = 0.298, Mf = 99.934 solar masses
# (3, 3, 0), chi = 0.219, Mf = 100.280 solar masses
# (2, 2, 1), chi = 0.980, Mf = 127.154 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.896, Mf = 79.381 solar masses
# (2, 2, 0), chi = 0.769, Mf = 87.560 solar masses
# (3, 0, 0), chi = 0.775, Mf = 97.741 solar masses
# (3, 1, 0), chi = 0.531, Mf = 101.134 solar masses
# (3, 2, 0), chi = 0.379, Mf = 102.532 solar masses
# (3, 3, 0), chi = 0.287, Mf = 103.141 solar masses
# (2, 2, 1), chi = 0.981, Mf = 127.971 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.908, Mf = 80.230 solar masses
# (2, 2, 0), chi = 0.787, Mf = 89.182 solar masses
# (3, 0, 0), chi = 0.839, Mf = 98.866 solar masses
# (3, 1, 0), chi = 0.604, Mf = 103.043 solar masses
# (3, 2, 0), chi = 0.448, Mf = 104.974 solar masses
# (3, 3, 0), chi = 0.346, Mf = 105.892 solar masses
# (2, 2, 1), chi = 0.982, Mf = 128.741 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.918, Mf = 81.010 solar masses
# (2, 2, 0), chi = 0.803, Mf = 90.731 solar masses
# (3, 0, 0), chi = 0.889, Mf = 99.866 solar masses
# (3, 1, 0), chi = 0.663, Mf = 104.791 solar masses
# (3, 2, 0), chi = 0.506, Mf = 107.275 solar masses
# (3, 3, 0), chi = 0.399, Mf = 108.540 solar masses
# (2, 2, 1), chi = 0.984, Mf = 129.466 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.927, Mf = 81.728 solar masses
# (2, 2, 0), chi = 0.817, Mf = 92.210 solar masses
# (3, 0, 0), chi = 0.928, Mf = 100.754 solar masses
# (3, 1, 0), chi = 0.711, Mf = 106.396 solar masses
# (3, 2, 0), chi = 0.556, Mf = 109.446 solar masses
# (3, 3, 0), chi = 0.446, Mf = 111.089 solar masses
# (2, 2, 1), chi = 0.985, Mf = 130.152 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.935, Mf = 82.389 solar masses
# (2, 2, 0), chi = 0.830, Mf = 93.625 solar masses
# (3, 0, 0), chi = 0.960, Mf = 101.543 solar masses
# (3, 1, 0), chi = 0.751, Mf = 107.873 solar masses
# (3, 2, 0), chi = 0.599, Mf = 111.496 solar masses
# (3, 3, 0), chi = 0.487, Mf = 113.544 solar masses
# (2, 2, 1), chi = 0.985, Mf = 130.801 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.942, Mf = 82.999 solar masses
# (2, 2, 0), chi = 0.841, Mf = 94.978 solar masses
# (3, 0, 0), chi = 0.986, Mf = 102.245 solar masses
# (3, 1, 0), chi = 0.785, Mf = 109.233 solar masses
# (3, 2, 0), chi = 0.636, Mf = 113.436 solar masses
# (3, 3, 0), chi = 0.524, Mf = 115.911 solar masses
# (2, 2, 1), chi = 0.986, Mf = 131.416 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.948, Mf = 83.562 solar masses
# (2, 2, 0), chi = 0.851, Mf = 96.273 solar masses
# (3, 1, 0), chi = 0.813, Mf = 110.488 solar masses
# (3, 2, 0), chi = 0.669, Mf = 115.272 solar masses
# (3, 3, 0), chi = 0.558, Mf = 118.192 solar masses
# (2, 2, 1), chi = 0.987, Mf = 132.000 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.953, Mf = 84.081 solar masses
# (2, 2, 0), chi = 0.861, Mf = 97.514 solar masses
# (3, 1, 0), chi = 0.838, Mf = 111.645 solar masses
# (3, 2, 0), chi = 0.698, Mf = 117.011 solar masses
# (3, 3, 0), chi = 0.588, Mf = 120.393 solar masses
# (2, 2, 1), chi = 0.988, Mf = 132.555 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.958, Mf = 84.561 solar masses
# (2, 2, 0), chi = 0.869, Mf = 98.704 solar masses
# (3, 1, 0), chi = 0.859, Mf = 112.714 solar masses
# (3, 2, 0), chi = 0.723, Mf = 118.659 solar masses
# (3, 3, 0), chi = 0.615, Mf = 122.518 solar masses
# (2, 2, 1), chi = 0.988, Mf = 133.083 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.962, Mf = 85.005 solar masses
# (2, 2, 0), chi = 0.877, Mf = 99.847 solar masses
# (3, 1, 0), chi = 0.877, Mf = 113.703 solar masses
# (3, 2, 0), chi = 0.745, Mf = 120.223 solar masses
# (3, 3, 0), chi = 0.640, Mf = 124.569 solar masses
# (2, 2, 1), chi = 0.989, Mf = 133.586 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.966, Mf = 85.416 solar masses
# (2, 2, 0), chi = 0.884, Mf = 100.943 solar masses
# (3, 1, 0), chi = 0.893, Mf = 114.617 solar masses
# (3, 2, 0), chi = 0.765, Mf = 121.708 solar masses
# (3, 3, 0), chi = 0.662, Mf = 126.550 solar masses
# (2, 2, 1), chi = 0.990, Mf = 134.066 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.969, Mf = 85.797 solar masses
# (2, 2, 0), chi = 0.890, Mf = 101.998 solar masses
# (3, 1, 0), chi = 0.907, Mf = 115.463 solar masses
# (3, 2, 0), chi = 0.783, Mf = 123.119 solar masses
# (3, 3, 0), chi = 0.682, Mf = 128.464 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.972, Mf = 86.149 solar masses
# (2, 2, 0), chi = 0.896, Mf = 103.011 solar masses
# (3, 1, 0), chi = 0.919, Mf = 116.246 solar masses
# (3, 2, 0), chi = 0.799, Mf = 124.459 solar masses
# (3, 3, 0), chi = 0.701, Mf = 130.314 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.975, Mf = 86.476 solar masses
# (2, 2, 0), chi = 0.902, Mf = 103.987 solar masses
# (3, 1, 0), chi = 0.930, Mf = 116.972 solar masses
# (3, 2, 0), chi = 0.814, Mf = 125.734 solar masses
# (3, 3, 0), chi = 0.718, Mf = 132.104 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.978, Mf = 86.779 solar masses
# (2, 2, 0), chi = 0.907, Mf = 104.927 solar masses
# (3, 1, 0), chi = 0.939, Mf = 117.645 solar masses
# (3, 2, 0), chi = 0.827, Mf = 126.948 solar masses
# (3, 3, 0), chi = 0.734, Mf = 133.836 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.980, Mf = 87.060 solar masses
# (2, 2, 0), chi = 0.912, Mf = 105.832 solar masses
# (3, 1, 0), chi = 0.948, Mf = 118.269 solar masses
# (3, 2, 0), chi = 0.839, Mf = 128.103 solar masses
# (3, 3, 0), chi = 0.748, Mf = 135.512 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.982, Mf = 87.321 solar masses
# (2, 2, 0), chi = 0.916, Mf = 106.705 solar masses
# (3, 1, 0), chi = 0.955, Mf = 118.848 solar masses
# (3, 2, 0), chi = 0.849, Mf = 129.204 solar masses
# (3, 3, 0), chi = 0.762, Mf = 137.134 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.984, Mf = 87.563 solar masses
# (2, 2, 0), chi = 0.920, Mf = 107.548 solar masses
# (3, 1, 0), chi = 0.962, Mf = 119.386 solar masses
# (3, 2, 0), chi = 0.859, Mf = 130.254 solar masses
# (3, 3, 0), chi = 0.774, Mf = 138.706 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.986, Mf = 87.787 solar masses
# (2, 2, 0), chi = 0.924, Mf = 108.361 solar masses
# (3, 1, 0), chi = 0.968, Mf = 119.886 solar masses
# (3, 2, 0), chi = 0.868, Mf = 131.256 solar masses
# (3, 3, 0), chi = 0.785, Mf = 140.229 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.987, Mf = 87.996 solar masses
# (2, 2, 0), chi = 0.927, Mf = 109.147 solar masses
# (3, 1, 0), chi = 0.974, Mf = 120.350 solar masses
# (3, 2, 0), chi = 0.876, Mf = 132.212 solar masses
# (3, 3, 0), chi = 0.796, Mf = 141.705 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.989, Mf = 88.189 solar masses
# (2, 2, 0), chi = 0.930, Mf = 109.907 solar masses
# (3, 1, 0), chi = 0.979, Mf = 120.782 solar masses
# (3, 2, 0), chi = 0.884, Mf = 133.125 solar masses
# (3, 3, 0), chi = 0.806, Mf = 143.137 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.990, Mf = 88.368 solar masses
# (2, 2, 0), chi = 0.933, Mf = 110.642 solar masses
# (3, 1, 0), chi = 0.983, Mf = 121.184 solar masses
# (3, 2, 0), chi = 0.891, Mf = 133.997 solar masses
# (3, 3, 0), chi = 0.815, Mf = 144.526 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.936, Mf = 111.352 solar masses
# (3, 1, 0), chi = 0.987, Mf = 121.559 solar masses
# (3, 2, 0), chi = 0.897, Mf = 134.831 solar masses
# (3, 3, 0), chi = 0.824, Mf = 145.874 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.939, Mf = 112.041 solar masses
# (3, 2, 0), chi = 0.903, Mf = 135.629 solar masses
# (3, 3, 0), chi = 0.832, Mf = 147.182 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.941, Mf = 112.708 solar masses
# (3, 2, 0), chi = 0.908, Mf = 136.393 solar masses
# (3, 3, 0), chi = 0.839, Mf = 148.453 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.469, Mf = 54.162 solar masses
# (2, 1, 1), chi = 0.190, Mf = 54.879 solar masses
# (2, 2, 1), chi = 0.108, Mf = 54.970 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.848, Mf = 58.681 solar masses
# (2, 1, 1), chi = 0.558, Mf = 62.153 solar masses
# (2, 2, 1), chi = 0.390, Mf = 63.342 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.732, Mf = 67.807 solar masses
# (2, 2, 1), chi = 0.565, Mf = 70.764 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.827, Mf = 72.162 solar masses
# (2, 2, 1), chi = 0.677, Mf = 77.287 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.884, Mf = 75.477 solar masses
# (2, 2, 1), chi = 0.752, Mf = 82.986 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.919, Mf = 77.974 solar masses
# (2, 2, 1), chi = 0.805, Mf = 87.958 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.943, Mf = 79.830 solar masses
# (2, 2, 1), chi = 0.842, Mf = 92.303 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.958, Mf = 81.183 solar masses
# (2, 2, 1), chi = 0.870, Mf = 96.115 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.970, Mf = 82.132 solar masses
# (2, 2, 1), chi = 0.891, Mf = 99.478 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.635, Mf = 47.575 solar masses
# (2, 1, 1), chi = 0.978, Mf = 82.750 solar masses
# (2, 2, 1), chi = 0.907, Mf = 102.462 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.344, Mf = 51.059 solar masses
# (2, 1, 1), chi = 0.984, Mf = 83.081 solar masses
# (2, 2, 1), chi = 0.920, Mf = 105.125 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.125, Mf = 54.346 solar masses
# (2, -1, 0), chi = 0.328, Mf = 54.077 solar masses
# (2, 1, 1), chi = 0.988, Mf = 83.133 solar masses
# (2, 2, 1), chi = 0.931, Mf = 107.516 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.313, Mf = 57.107 solar masses
# (2, 1, 0), chi = 0.088, Mf = 57.450 solar masses
# (2, 2, 0), chi = 0.046, Mf = 57.470 solar masses
# (2, 2, 1), chi = 0.939, Mf = 109.674 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.604, Mf = 58.771 solar masses
# (2, 1, 0), chi = 0.302, Mf = 60.168 solar masses
# (2, 2, 0), chi = 0.182, Mf = 60.446 solar masses
# (2, 2, 1), chi = 0.946, Mf = 111.630 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.748, Mf = 60.182 solar masses
# (2, 1, 0), chi = 0.446, Mf = 62.585 solar masses
# (2, 2, 0), chi = 0.292, Mf = 63.284 solar masses
# (2, 2, 1), chi = 0.952, Mf = 113.412 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.838, Mf = 61.373 solar masses
# (2, 1, 0), chi = 0.550, Mf = 64.771 solar masses
# (2, 2, 0), chi = 0.382, Mf = 65.989 solar masses
# (2, 2, 1), chi = 0.957, Mf = 115.042 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.901, Mf = 62.375 solar masses
# (2, 1, 0), chi = 0.629, Mf = 66.756 solar masses
# (2, 2, 0), chi = 0.457, Mf = 68.567 solar masses
# (3, -3, 0), chi = 0.828, Mf = 72.774 solar masses
# (2, 2, 1), chi = 0.961, Mf = 116.537 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.946, Mf = 63.214 solar masses
# (2, 1, 0), chi = 0.690, Mf = 68.562 solar masses
# (2, 2, 0), chi = 0.519, Mf = 71.021 solar masses
# (3, -3, 0), chi = 0.594, Mf = 76.748 solar masses
# (2, 2, 1), chi = 0.965, Mf = 117.916 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.980, Mf = 63.915 solar masses
# (2, 1, 0), chi = 0.738, Mf = 70.209 solar masses
# (2, 2, 0), chi = 0.571, Mf = 73.358 solar masses
# (3, -3, 0), chi = 0.402, Mf = 80.529 solar masses
# (2, 2, 1), chi = 0.968, Mf = 119.189 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.777, Mf = 71.710 solar masses
# (2, 2, 0), chi = 0.615, Mf = 75.581 solar masses
# (3, -3, 0), chi = 0.243, Mf = 84.136 solar masses
# (3, -2, 0), chi = 0.433, Mf = 83.611 solar masses
# (2, 2, 1), chi = 0.971, Mf = 120.370 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.809, Mf = 73.081 solar masses
# (2, 2, 0), chi = 0.653, Mf = 77.696 solar masses
# (3, -3, 0), chi = 0.109, Mf = 87.583 solar masses
# (3, -2, 0), chi = 0.174, Mf = 87.493 solar masses
# (2, 2, 1), chi = 0.973, Mf = 121.467 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.835, Mf = 74.332 solar masses
# (2, 2, 0), chi = 0.686, Mf = 79.708 solar masses
# (3, -1, 0), chi = 0.801, Mf = 87.017 solar masses
# (3, 1, 0), chi = 0.014, Mf = 90.880 solar masses
# (3, 2, 0), chi = 0.007, Mf = 90.881 solar masses
# (3, 3, 0), chi = 0.005, Mf = 90.881 solar masses
# (2, 2, 1), chi = 0.976, Mf = 122.490 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.856, Mf = 75.476 solar masses
# (2, 2, 0), chi = 0.715, Mf = 81.623 solar masses
# (3, -1, 0), chi = 0.971, Mf = 87.348 solar masses
# (3, 0, 0), chi = 0.483, Mf = 92.515 solar masses
# (3, 1, 0), chi = 0.241, Mf = 93.722 solar masses
# (3, 2, 0), chi = 0.146, Mf = 93.970 solar masses
# (3, 3, 0), chi = 0.102, Mf = 94.042 solar masses
# (2, 2, 1), chi = 0.977, Mf = 123.445 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.875, Mf = 76.523 solar masses
# (2, 2, 0), chi = 0.739, Mf = 83.445 solar masses
# (3, 0, 0), chi = 0.640, Mf = 94.020 solar masses
# (3, 1, 0), chi = 0.387, Mf = 96.161 solar masses
# (3, 2, 0), chi = 0.256, Mf = 96.831 solar masses
# (3, 3, 0), chi = 0.186, Mf = 97.074 solar masses
# (2, 2, 1), chi = 0.979, Mf = 124.339 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.890, Mf = 77.481 solar masses
# (2, 2, 0), chi = 0.761, Mf = 85.181 solar masses
# (3, 0, 0), chi = 0.742, Mf = 95.354 solar masses
# (3, 1, 0), chi = 0.494, Mf = 98.345 solar masses
# (3, 2, 0), chi = 0.347, Mf = 99.503 solar masses
# (3, 3, 0), chi = 0.259, Mf = 99.985 solar masses
# (2, 2, 1), chi = 0.981, Mf = 125.178 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.903, Mf = 78.360 solar masses
# (2, 2, 0), chi = 0.780, Mf = 86.835 solar masses
# (3, 0, 0), chi = 0.815, Mf = 96.536 solar masses
# (3, 1, 0), chi = 0.576, Mf = 100.327 solar masses
# (3, 2, 0), chi = 0.422, Mf = 102.007 solar masses
# (3, 3, 0), chi = 0.323, Mf = 102.781 solar masses
# (2, 2, 1), chi = 0.982, Mf = 125.966 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.914, Mf = 79.166 solar masses
# (2, 2, 0), chi = 0.797, Mf = 88.412 solar masses
# (3, 0, 0), chi = 0.871, Mf = 97.583 solar masses
# (3, 1, 0), chi = 0.641, Mf = 102.136 solar masses
# (3, 2, 0), chi = 0.485, Mf = 104.362 solar masses
# (3, 3, 0), chi = 0.380, Mf = 105.469 solar masses
# (2, 2, 1), chi = 0.983, Mf = 126.709 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.924, Mf = 79.907 solar masses
# (2, 2, 0), chi = 0.812, Mf = 89.917 solar masses
# (3, 0, 0), chi = 0.915, Mf = 98.511 solar masses
# (3, 1, 0), chi = 0.694, Mf = 103.793 solar masses
# (3, 2, 0), chi = 0.539, Mf = 106.580 solar masses
# (3, 3, 0), chi = 0.429, Mf = 108.054 solar masses
# (2, 2, 1), chi = 0.984, Mf = 127.409 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.932, Mf = 80.588 solar masses
# (2, 2, 0), chi = 0.825, Mf = 91.354 solar masses
# (3, 0, 0), chi = 0.949, Mf = 99.334 solar masses
# (3, 1, 0), chi = 0.738, Mf = 105.314 solar masses
# (3, 2, 0), chi = 0.585, Mf = 108.673 solar masses
# (3, 3, 0), chi = 0.473, Mf = 110.542 solar masses
# (2, 2, 1), chi = 0.985, Mf = 128.071 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.940, Mf = 81.214 solar masses
# (2, 2, 0), chi = 0.838, Mf = 92.727 solar masses
# (3, 0, 0), chi = 0.978, Mf = 100.064 solar masses
# (3, 1, 0), chi = 0.774, Mf = 106.712 solar masses
# (3, 2, 0), chi = 0.625, Mf = 110.648 solar masses
# ...
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.952, Mf = 62.030 solar masses
# (2, 2, 0), chi = 0.858, Mf = 71.792 solar masses
# (3, 1, 0), chi = 0.830, Mf = 82.259 solar masses
# (3, 2, 0), chi = 0.689, Mf = 86.090 solar masses
# (3, 3, 0), chi = 0.579, Mf = 88.482 solar masses
# (2, 2, 1), chi = 0.988, Mf = 97.849 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.958, Mf = 62.515 solar masses
# (2, 2, 0), chi = 0.870, Mf = 72.989 solar masses
# (3, 1, 0), chi = 0.859, Mf = 83.340 solar masses
# (3, 2, 0), chi = 0.724, Mf = 87.751 solar masses
# (3, 3, 0), chi = 0.616, Mf = 90.617 solar masses
# (2, 2, 1), chi = 0.989, Mf = 98.381 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.964, Mf = 62.952 solar masses
# (2, 2, 0), chi = 0.880, Mf = 74.121 solar masses
# (3, 1, 0), chi = 0.883, Mf = 84.312 solar masses
# (3, 2, 0), chi = 0.753, Mf = 89.298 solar masses
# (3, 3, 0), chi = 0.649, Mf = 92.653 solar masses
# (2, 2, 1), chi = 0.989, Mf = 98.879 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.969, Mf = 63.345 solar masses
# (2, 2, 0), chi = 0.889, Mf = 75.194 solar masses
# (3, 1, 0), chi = 0.903, Mf = 85.187 solar masses
# (3, 2, 0), chi = 0.779, Mf = 90.740 solar masses
# (3, 3, 0), chi = 0.677, Mf = 94.595 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.973, Mf = 63.700 solar masses
# (2, 2, 0), chi = 0.897, Mf = 76.211 solar masses
# (3, 1, 0), chi = 0.920, Mf = 85.976 solar masses
# (3, 2, 0), chi = 0.801, Mf = 92.086 solar masses
# (3, 3, 0), chi = 0.703, Mf = 96.451 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.976, Mf = 64.020 solar masses
# (2, 2, 0), chi = 0.904, Mf = 77.176 solar masses
# (3, 1, 0), chi = 0.934, Mf = 86.687 solar masses
# (3, 2, 0), chi = 0.820, Mf = 93.344 solar masses
# (3, 3, 0), chi = 0.725, Mf = 98.225 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.980, Mf = 64.309 solar masses
# (2, 2, 0), chi = 0.911, Mf = 78.094 solar masses
# (3, 1, 0), chi = 0.946, Mf = 87.329 solar masses
# (3, 2, 0), chi = 0.837, Mf = 94.521 solar masses
# (3, 3, 0), chi = 0.746, Mf = 99.921 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.982, Mf = 64.570 solar masses
# (2, 2, 0), chi = 0.917, Mf = 78.968 solar masses
# (3, 1, 0), chi = 0.956, Mf = 87.909 solar masses
# (3, 2, 0), chi = 0.851, Mf = 95.623 solar masses
# (3, 3, 0), chi = 0.764, Mf = 101.545 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.985, Mf = 64.806 solar masses
# (2, 2, 0), chi = 0.922, Mf = 79.801 solar masses
# (3, 1, 0), chi = 0.965, Mf = 88.434 solar masses
# (3, 2, 0), chi = 0.864, Mf = 96.657 solar masses
# (3, 3, 0), chi = 0.780, Mf = 103.100 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.987, Mf = 65.020 solar masses
# (2, 2, 0), chi = 0.927, Mf = 80.595 solar masses
# (3, 1, 0), chi = 0.973, Mf = 88.909 solar masses
# (3, 2, 0), chi = 0.875, Mf = 97.627 solar masses
# (3, 3, 0), chi = 0.795, Mf = 104.591 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.989, Mf = 65.213 solar masses
# (2, 2, 0), chi = 0.931, Mf = 81.354 solar masses
# (3, 1, 0), chi = 0.980, Mf = 89.340 solar masses
# (3, 2, 0), chi = 0.885, Mf = 98.538 solar masses
# (3, 3, 0), chi = 0.808, Mf = 106.021 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.935, Mf = 82.079 solar masses
# (3, 1, 0), chi = 0.986, Mf = 89.731 solar masses
# (3, 2, 0), chi = 0.894, Mf = 99.395 solar masses
# (3, 3, 0), chi = 0.820, Mf = 107.394 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.939, Mf = 82.773 solar masses
# (3, 2, 0), chi = 0.902, Mf = 100.202 solar masses
# (3, 3, 0), chi = 0.831, Mf = 108.712 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.942, Mf = 83.438 solar masses
# (3, 2, 0), chi = 0.910, Mf = 100.963 solar masses
# (3, 3, 0), chi = 0.841, Mf = 109.979 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.945, Mf = 84.075 solar masses
# (3, 2, 0), chi = 0.916, Mf = 101.680 solar masses
# (3, 3, 0), chi = 0.850, Mf = 111.197 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.948, Mf = 84.687 solar masses
# (3, 2, 0), chi = 0.922, Mf = 102.357 solar masses
# (3, 3, 0), chi = 0.858, Mf = 112.370 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.951, Mf = 85.274 solar masses
# (3, 2, 0), chi = 0.928, Mf = 102.997 solar masses
# (3, 3, 0), chi = 0.866, Mf = 113.499 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.953, Mf = 85.838 solar masses
# (3, 2, 0), chi = 0.932, Mf = 103.602 solar masses
# (3, 3, 0), chi = 0.873, Mf = 114.587 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.955, Mf = 86.381 solar masses
# (3, 2, 0), chi = 0.937, Mf = 104.175 solar masses
# (3, 3, 0), chi = 0.880, Mf = 115.636 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.957, Mf = 86.903 solar masses
# (3, 2, 0), chi = 0.941, Mf = 104.718 solar masses
# (3, 3, 0), chi = 0.886, Mf = 116.647 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.959, Mf = 87.406 solar masses
# (3, 2, 0), chi = 0.945, Mf = 105.233 solar masses
# (3, 3, 0), chi = 0.892, Mf = 117.623 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.961, Mf = 87.891 solar masses
# (3, 2, 0), chi = 0.948, Mf = 105.721 solar masses
# (3, 3, 0), chi = 0.897, Mf = 118.566 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.963, Mf = 88.358 solar masses
# (3, 2, 0), chi = 0.951, Mf = 106.185 solar masses
# (3, 3, 0), chi = 0.902, Mf = 119.477 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.964, Mf = 88.809 solar masses
# (3, 2, 0), chi = 0.954, Mf = 106.626 solar masses
# (3, 3, 0), chi = 0.906, Mf = 120.357 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.966, Mf = 89.245 solar masses
# (3, 2, 0), chi = 0.957, Mf = 107.045 solar masses
# (3, 3, 0), chi = 0.910, Mf = 121.209 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.967, Mf = 89.666 solar masses
# (3, 2, 0), chi = 0.959, Mf = 107.444 solar masses
# (3, 3, 0), chi = 0.914, Mf = 122.033 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.969, Mf = 90.073 solar masses
# (3, 2, 0), chi = 0.961, Mf = 107.824 solar masses
# (3, 3, 0), chi = 0.918, Mf = 122.830 solar masses
# Measurement compatible with modes:
# (2, 2, 0), chi = 0.970, Mf = 90.467 solar masses
# (3, 2, 0), chi = 0.963, Mf = 108.186 solar masses
# (3, 3, 0), chi = 0.922, Mf = 123.603 solar masses
# Measurement compatible with modes:
# (2, 0, 1), chi = 0.978, Mf = 45.121 solar masses
# (2, 1, 1), chi = 0.717, Mf = 49.939 solar masses
# (2, 2, 1), chi = 0.548, Mf = 51.967 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.843, Mf = 54.236 solar masses
# (2, 2, 1), chi = 0.697, Mf = 58.442 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.906, Mf = 57.204 solar masses
# (2, 2, 1), chi = 0.785, Mf = 63.839 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.941, Mf = 59.211 solar masses
# (2, 2, 1), chi = 0.840, Mf = 68.334 solar masses
# Measurement compatible with modes:
# (2, 1, 1), chi = 0.962, Mf = 60.524 solar masses
# (2, 2, 1), chi = 0.876, Mf = 72.103 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.773, Mf = 34.298 solar masses
# (2, 1, 1), chi = 0.975, Mf = 61.321 solar masses
# (2, 2, 1), chi = 0.902, Mf = 75.292 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.354, Mf = 37.833 solar masses
# (2, 1, 1), chi = 0.983, Mf = 61.711 solar masses
# (2, 2, 1), chi = 0.920, Mf = 78.021 solar masses
# Measurement compatible with modes:
# (2, -2, 0), chi = 0.067, Mf = 41.098 solar masses
# (2, -1, 0), chi = 0.151, Mf = 41.055 solar masses
# (2, 1, 1), chi = 0.989, Mf = 61.722 solar masses
# (2, 2, 1), chi = 0.934, Mf = 80.380 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.531, Mf = 43.253 solar masses
# (2, 1, 0), chi = 0.238, Mf = 44.027 solar masses
# (2, 2, 0), chi = 0.139, Mf = 44.150 solar masses
# (2, 2, 1), chi = 0.944, Mf = 82.438 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.748, Mf = 44.707 solar masses
# (2, 1, 0), chi = 0.446, Mf = 46.492 solar masses
# (2, 2, 0), chi = 0.292, Mf = 47.011 solar masses
# (2, 2, 1), chi = 0.952, Mf = 84.249 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.862, Mf = 45.864 solar masses
# (2, 1, 0), chi = 0.580, Mf = 48.642 solar masses
# (2, 2, 0), chi = 0.409, Mf = 49.694 solar masses
# (2, 2, 1), chi = 0.959, Mf = 85.855 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.933, Mf = 46.779 solar masses
# (2, 1, 0), chi = 0.673, Mf = 50.532 solar masses
# (2, 2, 0), chi = 0.501, Mf = 52.207 solar masses
# (3, -3, 0), chi = 0.661, Mf = 56.121 solar masses
# (2, 2, 1), chi = 0.964, Mf = 87.288 solar masses
# Measurement compatible with modes:
# (2, 0, 0), chi = 0.981, Mf = 47.498 solar masses
# (2, 1, 0), chi = 0.740, Mf = 52.200 solar masses
# (2, 2, 0), chi = 0.573, Mf = 54.559 solar masses
# (3, -3, 0), chi = 0.395, Mf = 59.927 solar masses
# (2, 2, 1), chi = 0.968, Mf = 88.576 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.790, Mf = 53.673 solar masses
# (2, 2, 0), chi = 0.631, Mf = 56.759 solar masses
# (3, -3, 0), chi = 0.189, Mf = 63.499 solar masses
# (3, -2, 0), chi = 0.320, Mf = 63.283 solar masses
# (2, 2, 1), chi = 0.972, Mf = 89.738 solar masses
# Measurement compatible with modes:
# (2, 1, 0), chi = 0.828, Mf = 54.976 solar masses
# (2, 2, 0), chi = 0.678, Mf = 58.817 solar masses
# (3, -3, 0), chi = 0.024, Mf = 66.862 solar masses
# (3, -2, 0), chi = 0.037, Mf = 66.859 solar masses
# (3, -1, 0), chi = 0.725, Mf = 64.634 solar masses
# (2, 2, 1), chi = 0.975, Mf = 90.793 solar masses
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15058/3133642293.py in <module>
#       9 for f_star in f_array:
#      10     for tau_star in tau_array:
# ---> 11         chi_Mf = bh_spectroscopy(f_star, tau_star, plot=False)
#      12         if chi_Mf is not None:
#      13             chi = chi_Mf[0]
#
# /tmp/ipykernel_15058/3002852323.py in bh_spectroscopy(f_star, tau_star, plot)
#      60             else:
#      61                 for m in range(-l,l+1):
# ---> 62                     result = minimize(
#      63                         fun,
#      64                         x0=0.5,
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     690                                  **options)
#     691     elif meth == 'l-bfgs-b':
# --> 692         res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     693                                callback=callback, **options)
#     694     elif meth == 'tnc':
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     360             # until the completion of the current minimization iteration.
#     361             # Overwrite f and g:
# --> 362             f, g = func_and_grad(x)
#     363         elif task_str.startswith(b'NEW_X'):
#     364             # new iteration
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     284             self._update_x_impl(x)
#     285         self._update_fun()
# --> 286         self._update_grad()
#     287         return self.f, self.g
#     288
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     254     def _update_grad(self):
#     255         if not self.g_updated:
# --> 256             self._update_grad_impl()
#     257             self.g_updated = True
#     258
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     171                 self._update_fun()
#     172                 self.ngev += 1
# --> 173                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                                            **finite_diff_options)
#     175
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     503
#     504         if sparsity is None:
# --> 505             return _dense_difference(fun_wrapped, x0, f0, h,
#     506                                      use_one_sided, method)
#     507         else:
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574             x = x0 + h_vecs[i]
#     575             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576             df = fun(x) - f0
#     577         elif method == '3-point' and use_one_sided[i]:
#     578             x1 = x0 + h_vecs[i]
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     454
#     455     def fun_wrapped(x):
# --> 456         f = np.atleast_1d(fun(x, *args, **kwargs))
#     457         if f.ndim > 1:
#     458             raise RuntimeError("`fun` return value has "
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     135             # Overwriting results in undefined behaviour because
#     136             # fun(self.x) will change self.x, with the two no longer linked.
# --> 137             fx = fun(np.copy(x), *args)
#     138             # Make sure the function returns a true scalar
#     139             if not np.isscalar(fx):
#
# /tmp/ipykernel_15058/2288248401.py in fun(chi, Q_star, l, m, n)
#       1 def fun(chi, Q_star, l, m, n):
#       2
# ----> 3     omega = qnm.omega(l, m, n, 1, chi)
#       4     f = np.real(omega)/(2*np.pi)
#       5     tau = -1/np.imag(omega)
#
# ~/Documents/Ringdown/NR_fitting/qnmfits/qnmfits/qnm.py in omega(self, l, m, n, sign, chif, Mf)
#     135
#     136             omega_interp = self.interpolated_qnm_funcs[l,m,n][0]
# --> 137             omega = omega_interp[0](chif) + 1j*omega_interp[1](chif)
#     138
#     139         # Use symmetry properties to get the mirror mode, if requested
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/interpolate/_polyint.py in __call__(self, x)
#      76         """
#      77         x, x_shape = self._prepare_x(x)
# ---> 78         y = self._evaluate(x)
#      79         return self._finish_y(y, x_shape)
#      80
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/interpolate/_interpolate.py in _evaluate(self, x_new)
#     691         #    The behavior is set by the bounds_error variable.
#     692         x_new = asarray(x_new)
# --> 693         y_new = self._call(self, x_new)
#     694         if not self._extrapolate:
#     695             below_bounds, above_bounds = self._check_bounds(x_new)
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/interpolate/_interpolate.py in _call_spline(self, x_new)
#     679
#     680     def _call_spline(self, x_new):
# --> 681         return self._spline(x_new)
#     682
#     683     def _call_nan_spline(self, x_new):
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/interpolate/_bsplines.py in __call__(self, x, nu, extrapolate)
#     458         out = np.empty((len(x), prod(self.c.shape[1:])), dtype=self.c.dtype)
#     459         self._ensure_c_contiguous()
# --> 460         self._evaluate(x, nu, extrapolate, out)
#     461         out = out.reshape(x_shape + self.c.shape[1:])
#     462         if self.axis != 0:
#
# ~/miniconda3/envs/qnmfits/lib/python3.10/site-packages/scipy/interpolate/_bsplines.py in _evaluate(self, xp, nu, extrapolate, out)
#     468
#     469     def _evaluate(self, xp, nu, extrapolate, out):
# --> 470         _bspl.evaluate_spline(self.t, self.c.reshape(self.c.shape[0], -1),
#     471                 self.k, xp, nu, extrapolate, out)
#     472
#
# KeyboardInterrupt:
